# %% [markdown]
# ### Importing all the required libraries

# %%
import cv2
import csv
import os
import string
import requests
import pandas as pd
import numpy as np
from PIL import Image, ImageOps
from IPython.display import clear_output as cls
from glob import glob
from tqdm import tqdm
import tensorflow.data as tfd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ### Counting PNG Images in the Training Dataset Directory

# %%
a=0
for filename in os.listdir("training_data_gan"):
  if filename.endswith('.png'):
    a+=1

print(a)
# Out:
# 9225

# %% [markdown]
# ### Generating CSV Metadata File for Word Image Dataset
# This function creates a CSV file containing filenames and their corresponding word labels (derived from the filename) for all images in the 'training_data_gan' folder, excluding files named exactly .png. This CSV acts as metadata for training the GAN.

# %%
def create_csv_from_folder(folder_path, csv_file_path):
    # Getting a list of all files in the folder
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    # Creating or overwriting the CSV file
    with open(csv_file_path, 'w', newline='') as csv_file:
        # Create a CSV writer object
        csv_writer = csv.writer(csv_file)

        # Writing the header row
        csv_writer.writerow(['FILENAME', 'IDENTITY'])

        # Writing data rows, excluding files with the name ".png"
        for file_name in files:
            if file_name.lower() == ".png":
                continue  # Skipping files with the name ".png"

            # file_path = os.path.join(folder_path, file_name)

            # Removing the file extension (assuming it's three characters long, like '.png')
            file_name_without_extension = os.path.splitext(file_name)[0]

            csv_writer.writerow([file_name, file_name_without_extension])

    print(f'CSV file "{csv_file_path}" created successfully.')

# Training data
training_data = "training_data_gan"
train_csv_path = './training_data.csv'
create_csv_from_folder(training_data, train_csv_path)
# Out:
# CSV file "./training_data.csv" created successfully.

# %%
df = pd.read_csv('training_data.csv')
df.shape
# Out:
# (9225, 2)

# %% [markdown]
# ### Extracting the first meaningful word from each entry using two split() operations

# %%
df['IDENTITY'] = df['IDENTITY'].apply(lambda x: x.split('_')[0]).apply(lambda x: x.split(' ')[0])

# %%
df.to_csv('train.csv', index=False)
df.head()
# Out:
#           FILENAME IDENTITY
# 0        & (1).png        &
# 1  & (1)_rot-1.png        &
# 2  & (1)_rot-2.png        &
# 3   & (1)_rot1.png        &
# 4   & (1)_rot2.png        &

# %% [markdown]
# ### Defining File Paths for Training Data and Metadata CSV

# %%
# File Paths
train_csv_path = './train.csv'
train_image_dir = 'training_data_gan'

# %% [markdown]
# ###  Loading Training Metadata CSV into a DataFrame

# %%
# Train CSV
train_csv = pd.read_csv(train_csv_path)

# %% [markdown]
# Extracting Word Labels from the DataFrame

# %%
labels = [str(word) for word in df['IDENTITY'].to_numpy()]
labels[:10]
# Out:
# ['&', '&', '&', '&', '&', '&', '&', '&', '&', '&']

# %% [markdown]
# ### Identifying Unique Characters in the Dataset

# %%
# Unique characters
unique_chars = set(char for word in labels for char in word)
n_classes = len(unique_chars)

# Show
print(f"Total number of unique characters : {n_classes}")
print(f"Unique Characters : \n{unique_chars}")
# Out:
# Total number of unique characters : 43
# Unique Characters :
# {'y', 'P', 'H', 'a', 'b', 'N', ',', 'g', 'T', 'l', 'V', 'C', 'd', 'p', 'r', 'z', 'G', 'j', 'q', 'R', 'Y', 'n', 'u', 'i', 'S', 'm', 'o', 'A', 'h', 'c', 't', 's', 'F', 'x', '-', 'M', '&', 'J', 'e', 'Q', 'B', 'E', 'O'}

# %% [markdown]
# ### Appending Directory Path to Image Filenames in Metadata

# %%
train_csv['FILENAME'] = [train_image_dir + f"/{filename}" for filename in train_csv['FILENAME']]

# %%
train_csv.head()
# Out:
#                             FILENAME IDENTITY
# 0        training_data_gan/& (1).png        &
# 1  training_data_gan/& (1)_rot-1.png        &
# 2  training_data_gan/& (1)_rot-2.png        &
# 3   training_data_gan/& (1)_rot1.png        &
# 4   training_data_gan/& (1)_rot2.png        &

# %% [markdown]
# ### Custom Keras Dataset Class for Loading and Preprocessing Word Images

# %%
# Continuing building the dataset class and model setup

class CharacterDatasetFromCSV(tf.keras.utils.Sequence):
    def __init__(self, df, img_size=200, batch_size=32):
        self.df = df
        self.img_size = img_size
        self.batch_size = batch_size
        self.classes = sorted(df["IDENTITY"].unique())
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}
        self.idx_to_class = {i: c for c, i in self.class_to_idx.items()}
        self.image_label_pairs = list(zip(df["FILENAME"], df["IDENTITY"]))
        np.random.shuffle(self.image_label_pairs)

    def __len__(self):
        return (len(self.image_label_pairs) + self.batch_size - 1) // self.batch_size

    def __getitem__(self, idx):
        batch_data = self.image_label_pairs[idx * self.batch_size:(idx + 1) * self.batch_size]
        images, labels = [], []
        for path, label in batch_data:
            img = Image.open(path).convert("L").resize((self.img_size, self.img_size))
            img = np.array(img) / 127.5 - 1.0
            images.append(img)
            labels.append(self.class_to_idx[label])
        images = np.expand_dims(np.array(images), axis=-1)
        labels = np.array(labels)
        return images, labels

# %% [markdown]
# ### Initializing Dataset and Computing Number of Unique Word Classes

# %%
dataset = CharacterDatasetFromCSV(train_csv, img_size=200, batch_size=32)
num_classes = len(dataset.class_to_idx)
print(num_classes)
# Out:
# 43

# %% [markdown]
# ### Building the Conditional GAN Generator Model

# %%
from tensorflow.keras.models import Model

z_dim = 100

# Building the Generator

def build_generator(z_dim=100, img_size=200, num_classes=num_classes):
    noise_input = layers.Input(shape=(z_dim,))
    label_input = layers.Input(shape=(1,), dtype=tf.int32)
    label_embedding = layers.Embedding(num_classes, z_dim)(label_input)
    label_embedding = layers.Flatten()(label_embedding)
    x = layers.Concatenate()([noise_input, label_embedding])
    x = layers.Dense(25 * 25 * 256, use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((25, 25, 256))(x)
    x = layers.Conv2DTranspose(128, kernel_size=5, strides=2, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(64, kernel_size=5, strides=2, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(32, kernel_size=5, strides=2, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(1, kernel_size=5, strides=1, padding="same", activation="tanh")(x)
    return Model([noise_input, label_input], x)

# %% [markdown]
# ### Defining the Conditional GAN Discriminator, Loss Functions, and Training Step

# %%
# Building the Discriminator

def build_discriminator(img_size=200, num_classes=num_classes):
    img_input = layers.Input(shape=(img_size, img_size, 1))
    label_input = layers.Input(shape=(1,), dtype=tf.int32)
    label_embedding = layers.Embedding(num_classes, img_size * img_size)(label_input)
    label_embedding = layers.Flatten()(label_embedding)
    label_embedding = layers.Reshape((img_size, img_size, 1))(label_embedding)
    x = layers.Concatenate()([img_input, label_embedding])
    x = layers.Conv2D(64, 5, strides=2, padding="same")(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv2D(128, 5, strides=2, padding="same")(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1, activation="sigmoid")(x)
    return Model([img_input, label_input], x)

generator = build_generator(z_dim=z_dim, img_size=200, num_classes=num_classes)
discriminator = build_discriminator(img_size=200, num_classes=num_classes)

cross_entropy = tf.keras.losses.BinaryCrossentropy()
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def train_step(images, labels):
    if images.shape[0] == 0:
        return tf.constant(0.0), tf.constant(0.0)

    # Converting both to tensors
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    labels = tf.convert_to_tensor(labels, dtype=tf.int32)
    labels = tf.reshape(labels, (-1, 1))

    noise = tf.random.normal([tf.shape(images)[0], z_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator([noise, labels], training=True)
        real_output = discriminator([images, labels], training=True)
        fake_output = discriminator([generated_images, labels], training=True)

        g_loss = generator_loss(fake_output)
        d_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(g_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(d_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return g_loss, d_loss

# %% [markdown]
# ### Displaying Class-to-Index Mapping for Word Labels

# %%
for char, idx in dataset.class_to_idx.items():
    print(f"Character: {char} --> Index: {idx}")
# Out:
# Character: & --> Index: 0
# Character: , --> Index: 1
# Character: - --> Index: 2
# Character: A --> Index: 3
# Character: B --> Index: 4
# Character: C --> Index: 5
# Character: E --> Index: 6
# Character: F --> Index: 7
# Character: G --> Index: 8
# Character: H --> Index: 9
# Character: J --> Index: 10
# Character: M --> Index: 11
# Character: N --> Index: 12
# Character: O --> Index: 13
# Character: P --> Index: 14
# Character: Q --> Index: 15
# Character: R --> Index: 16
# Character: S --> Index: 17
# Character: T --> Index: 18
# Character: V --> Index: 19
# Character: Y --> Index: 20
# Character: a --> Index: 21
# Character: b --> Index: 22
# Character: c --> Index: 23
# Character: d --> Index: 24
# Character: e --> Index: 25
# Character: g --> Index: 26
# Character: h --> Index: 27
# Character: i --> Index: 28
# Character: j --> Index: 29
# Character: l --> Index: 30
# Character: m --> Index: 31
# Character: n --> Index: 32
# Character: o --> Index: 33
# Character: p --> Index: 34
# Character: q --> Index: 35
# Character: r --> Index: 36
# Character: s --> Index: 37
# Character: t --> Index: 38
# Character: u --> Index: 39
# Character: x --> Index: 40
# Character: y --> Index: 41
# Character: z --> Index: 42

# %% [markdown]
# ### Visualizing Sample Generated Character Images for Given Label Indices

# %%
# import matplotlib.pyplot as plt

# def show_generated_images_for_labels(generator, label_indices, z_dim=100):
#     if len(label_indices) != 3:
#         raise ValueError("Please provide exactly 3 label indices")

#     noise = tf.random.normal([3, z_dim])
#     labels = tf.constant(label_indices, dtype=tf.int32)
#     labels = tf.reshape(labels, (-1, 1))
#     generated_images = generator([noise, labels], training=False)
#     generated_images = (generated_images + 1) / 2.0  # Rescale to [0, 1]

#     fig, axs = plt.subplots(1, 3, figsize=(6, 2))
#     for i in range(3):
#         axs[i].imshow(generated_images[i, :, :, 0], cmap='binary_r')
#         axs[i].set_title(f"Label {label_indices[i]}")
#         axs[i].axis('off')
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# ### Training the Conditional GAN and Saving Generator Models Across Epochs

# %%
# from tqdm import trange
# import time
# import tensorflow as tf
# import os
# import matplotlib.pyplot as plt

# # Directory to save models
# save_dir = "saved_generators"
# os.makedirs(save_dir, exist_ok=True)

# # Loss tracking
# g_losses = []
# d_losses = []

# epochs = 100

# for epoch in range(epochs):
#     print(f"\nEpoch {epoch + 1}/{epochs}")
#     start_time = time.time()

#     total_batches = len(dataset)
#     for batch_idx in trange(total_batches, desc="Training", ncols=100):
#         images, labels = dataset[batch_idx]
#         g_loss, d_loss = train_step(images, labels)

#     print(f"Epoch {epoch + 1} completed in {time.time() - start_time:.2f}s")
#     print(f"  Final Batch Losses -> G: {g_loss:.4f} | D: {d_loss:.4f}")

#     # Track losses
#     g_losses.append(g_loss)
#     d_losses.append(d_loss)

#     # Save generator with epoch number (no overwrite)
#     epoch_save_path = os.path.join(save_dir, f"generator_epoch_{epoch + 1:03d}.h5")
#     generator.save(epoch_save_path)
#     print(f" Generator saved: {epoch_save_path}")

#     # Display samples
#     label_indices = [0, 19, 37]  # Replace with any 3 labels you'd like to visualize
#     show_generated_images_for_labels(generator, label_indices)

# # === Plotting Loss Curves After Training ===
# plt.figure(figsize=(8, 5))
# plt.plot(range(1, len(g_losses) + 1), g_losses, label='Generator Loss')
# plt.plot(range(1, len(d_losses) + 1), d_losses, label='Discriminator Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Generator and Discriminator Loss Over Epochs')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Loading a Pretrained Generator Model from Checkpoint

# %%
from tensorflow.keras.models import load_model

# Loading the best saved generator model
generator = load_model("generator_epoch_061.h5")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import zipfile

with zipfile.ZipFile("Transcripts.zip", 'r') as zip_ref:
    zip_ref.extractall(".")  # "." indicates the current directory

# %% [markdown]
# ### Extracting and Formatting Word-Level Transcripts from .docx Files
#
# This script processes .docx documents containing text segmented by headings like "PDF p1", "PDF p2", etc., and converts the content into clean word-level transcripts.

# %%
import re
import os
from docx import Document

# Path to the specific .docx file
docx_folder = "Transcripts"
file_name = "Mendo transcription.docx"
docx_path = os.path.join(docx_folder, file_name)

# Output folder for transcripts
transcripts_folder = "Transcript to txt"
os.makedirs(transcripts_folder, exist_ok=True)

# Load the document
doc = Document(docx_path)

# Extracting base name of the document (without extension)
docx_name = os.path.splitext(file_name)[0]

# Initializing variables
page_content = {}
current_page = None

# Reading document and segregate by "PDF pX" headings
for para in doc.paragraphs:
    text = para.text.strip()

    # Detect headers like "PDF p1", "PDF p2", etc.
    if re.match(r"^PDF p\d+", text):
        current_page = text  # Example: "PDF p1"
        page_content[current_page] = []
    elif current_page:  # Store content under the detected page header
        page_content[current_page].append(text)

# Processing each page and save to corresponding .txt file
for page, content in page_content.items():
    # Extracting the page number from "PDF pX"
    page_number = re.search(r"\d+", page).group()

    # Generating output file name
    output_file = os.path.join(transcripts_folder, f"{docx_name}_page_{page_number}_transcript.txt")

    # Flattening content into a single string
    full_text = " ".join(content)

    # Splitting into words (treating punctuation as separate words)
    words = re.findall(r"[\w]+|[^\w\s]", full_text)

    # Saving to file (one word per line)
    with open(output_file, "w", encoding="utf-8") as f:
        previous_word = None  # To store the last word

        for word in words:
            if word == "-":
                if previous_word is not None:
                    previous_word += "-"
            elif word == ",":
                if previous_word is not None:
                    previous_word += ","
            else:
                if previous_word is not None:
                    f.write(previous_word + "\n")  # Writing the previous word
                previous_word = word  # Updating previous word

        # Writing the last word if it exists
        if previous_word is not None:
            f.write(previous_word + "\n")

    print(f"Saved: {output_file}")

print("Processing complete! Transcripts saved in the 'Transcript to txt' folder.")
# Out:
# Saved: Transcript to txt\Mendo transcription_page_1_transcript.txt
# Saved: Transcript to txt\Mendo transcription_page_2_transcript.txt
# Saved: Transcript to txt\Mendo transcription_page_3_transcript.txt
# Saved: Transcript to txt\Mendo transcription_page_4_transcript.txt
# Saved: Transcript to txt\Mendo transcription_page_5_transcript.txt
# Processing complete! Transcripts saved in the 'Transcript to txt' folder.

# %% [markdown]
# ### Generating and Saving Aligned Synthetic Word Images from Text Files Using a Trained Generator
# This script enables word-level image generation using a trained Conditional GAN generator, with proper typographic alignment and batch processing from .txt files

# %% [markdown]
# ### Key Components:
#
# - **Character Grouping:**
#   Categorizes characters into ascenders, descenders, x-height letters, and punctuation to ensure accurate vertical alignment.
#
# - **`trim_whitespace()`:**
#   Removes blank margins from generated characters to eliminate unnecessary padding.
#
# - **`resize_and_baseline_align()`:**
#   Resizes and vertically aligns each character based on its typographic role:
#   - Punctuation like commas sits lower,
#   - Ascenders reach the top,
#   - Descenders dip below the baseline.
#
# - **`generate_and_save_word_image()`:**
#   - Converts a word into valid character labels.
#   - Generates images for each character.
#   - Applies smoothing, alignment, and spacing.
#   - Concatenates characters into a word image.
#   - Saves the final image as a PNG in the specified output folder.
#
# - **`generate_from_all_txt()`:**
#   - Iterates through all `.txt` files in a given folder.
#   - Reads word lists from each file.
#   - Generates and saves word images using the generator model.
#   - Organizes outputs into subfolders named after each input file.

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter, zoom
from PIL import Image

# Character groups
descenders = {'g', 'j', 'p', 'q', 'y'}
ascenders = {'b', 'd', 'h', 'l', 't'}
xheight_letters = set('abcdeghijlmnopqrstuvxyz') - descenders - ascenders
punctuation = {',', '-'}

def trim_whitespace(image, threshold=0.9):
    mask = image < threshold
    rows = np.any(mask, axis=1)
    cols = np.any(mask, axis=0)
    return image[np.ix_(rows, cols)]

def resize_and_baseline_align(img, char, full_height, reference_height=None,
                               xheight=0.6, descender_frac=0.25, punctuation_scale=0.4):
    """
    Resize and baseline-align character images according to typographic role.
    Handling proper vertical alignment for punctuation based on previous character.
    """
    if char == ',':
        target_height = int(full_height * punctuation_scale)
        resized = zoom(img, (target_height / img.shape[0], target_height / img.shape[0]), order=1)
        pad_top = full_height - target_height
        pad_bottom = 0
        total_height = full_height

    elif char == '-' and reference_height:
        target_height = int(full_height * punctuation_scale)
        resized = zoom(img, (target_height / img.shape[0], target_height / img.shape[0]), order=1)

        # Centering the hyphen vertically w.r.t. the previous character image height
        midline = reference_height // 2
        pad_top = midline - target_height // 2
        pad_bottom = full_height - target_height - pad_top
        total_height = full_height

    elif char.isupper() or char in ascenders:
        target_height = full_height
        resized = zoom(img, (target_height / img.shape[0], target_height / img.shape[0]), order=1)
        pad_top = 0
        pad_bottom = 0
        total_height = full_height

    elif char in xheight_letters:
        target_height = int(full_height * xheight)
        resized = zoom(img, (target_height / img.shape[0], target_height / img.shape[0]), order=1)
        pad_top = full_height - target_height
        pad_bottom = 0
        total_height = full_height

    elif char in descenders:
        x_part = int(full_height * xheight)
        d_part = int(full_height * descender_frac)
        target_height = x_part + d_part
        resized = zoom(img, (target_height / img.shape[0], target_height / img.shape[0]), order=1)
        pad_top = full_height - x_part
        pad_bottom = 0
        total_height = full_height + d_part

    else:
        resized = zoom(img, (full_height / img.shape[0], full_height / img.shape[0]), order=1)
        pad_top = 0
        pad_bottom = 0
        total_height = full_height

    padded = np.pad(resized, ((pad_top, pad_bottom), (0, 0)), mode='constant', constant_values=1.0)
    return padded, padded.shape[0]  # return actual rendered height

def generate_and_save_word_image(generator, word, class_to_idx, save_path, z_dim=100):
    word_for_generation = word.replace('v', 'u')
    valid_chars = [c for c in word_for_generation if c in class_to_idx]

    if not valid_chars:
        print(f"Skipping '{word}' – no valid characters.")
        return

    label_indices = [class_to_idx[c] for c in valid_chars]
    noise = tf.random.normal([len(label_indices), z_dim])
    labels = tf.constant(label_indices, dtype=tf.int32)
    labels = tf.reshape(labels, (-1, 1))

    generated_images = generator([noise, labels], training=False)
    generated_images = (generated_images + 1) / 2.0
    images_np = generated_images.numpy()
    images_np = np.squeeze(images_np, axis=-1)

    trimmed_images = [trim_whitespace(gaussian_filter(img, sigma=0.5)) for img in images_np]
    full_height = max(img.shape[0] for img in trimmed_images)

    aligned_images = []
    for i, char in enumerate(valid_chars):
        # Getting actual height of previous rendered image (if needed)
        ref_height = aligned_images[-1].shape[0] if char == '-' and i > 0 else None
        aligned, _ = resize_and_baseline_align(trimmed_images[i], char, full_height, reference_height=ref_height)
        aligned_images.append(aligned)

    # Matching height across all characters
    max_total_height = max(img.shape[0] for img in aligned_images)
    final_images = [
        np.pad(img, ((0, max_total_height - img.shape[0]), (0, 0)), mode='constant', constant_values=1.0)
        for img in aligned_images
    ]

    # Adding spacing except before punctuation
    spaced_images = []
    for i, img in enumerate(final_images):
        spaced_images.append(img)
        if i < len(final_images) - 1 and valid_chars[i + 1] not in punctuation:
            spacing = np.ones((max_total_height, 3))  # small gap
            spaced_images.append(spacing)

    word_image = np.concatenate(spaced_images, axis=1)
    img_uint8 = (word_image * 255).astype(np.uint8)
    img_pil = Image.fromarray(img_uint8)
    img_pil.save(os.path.join(save_path, f"{word}.png"))

def generate_from_all_txt(generator, input_folder, class_to_idx, z_dim=100, root_output_dir="gan_generated_words"):
    os.makedirs(root_output_dir, exist_ok=True)

    # Looping through all .txt files in the folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            txt_path = os.path.join(input_folder, filename)
            base_name = os.path.splitext(filename)[0]
            output_dir = os.path.join(root_output_dir, f"words_dataset_{base_name}")
            os.makedirs(output_dir, exist_ok=True)

            with open(txt_path, 'r') as f:
                words = [line.strip() for line in f if line.strip()]

            for word in words:
                generate_and_save_word_image(generator, word, class_to_idx, output_dir, z_dim=z_dim)

# %%
generate_from_all_txt(generator, input_folder="Transcript to txt", class_to_idx=dataset.class_to_idx, z_dim=100)
# Out:
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '(' – no valid characters.
# Skipping ')' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping 'I' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping 'I' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ':' – no valid characters.
# Skipping ':' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ':' – no valid characters.
# Skipping ':' – no valid characters.
# Skipping ':' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping 'I' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '15' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '1659' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping 'I' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping 'D' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '?' – no valid characters.
# Skipping '?' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '3' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '1656' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping ';' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '1656' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '27' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '1656' – no valid characters.
# Skipping '.' – no valid characters.
# Skipping '.' – no valid characters.

# %% [markdown]
# ### Converting PDF Pages to Images Using PyMuPDF (fitz)
#
# This script converts the first 5 pages of a given PDF into PNG images using the PyMuPDF (fitz) library and saves them in a structured folder format.

# %%
import os
import fitz  # PyMuPDF

# Define the name of the PDF file in the current directory
file_name = "Mendo - Principe perfecto.pdf"  # Replace this with your desired PDF file name
pdf_path = os.path.abspath(file_name)

# Define the output base folder
output_base_folder = "pdf_to_images"
os.makedirs(output_base_folder, exist_ok=True)

def pdf_to_images(pdf_path, output_folder):
    pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]
    pdf_output_folder = os.path.join(output_folder, pdf_name)
    os.makedirs(pdf_output_folder, exist_ok=True)

    doc = fitz.open(pdf_path)

    for i, page in enumerate(doc, start=1):
        if i <= 5:  # Saving only the first 3 pages
            pix = page.get_pixmap()
            image_path = os.path.join(pdf_output_folder, f"{pdf_name}_page_{i}.png")
            pix.save(image_path)

    print(f"Images saved in folder: {pdf_output_folder}")

# Process the PDF file
pdf_to_images(pdf_path, output_base_folder)
# Out:
# Images saved in folder: pdf_to_images\Mendo - Principe perfecto

# %% [markdown]
# #### OCR-Based Word Segmentation and Image Cropping from PDF-Derived Page Images
#
# This script uses Tesseract OCR to detect and crop individual word images from page-level PNG images (extracted from PDFs), saving each word as a separate image file.

# %%
import os
import cv2
import pytesseract
import pandas as pd
from PIL import Image

# Folder containing input images
input_folder = "pdf_to_images"
output_base = "ocr_generated_words"
os.makedirs(output_base, exist_ok=True)

# Function to process a single image
def process_image(image_path):
    base_name = os.path.splitext(os.path.basename(image_path))[0]
    output_folder = os.path.join(output_base, f"{base_name}_words")
    os.makedirs(output_folder, exist_ok=True)

    # Load and prepare image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to read: {image_path}")
        return
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pil_image = Image.fromarray(image_rgb)

    # OCR with bounding box data
    custom_config = r'--oem 3 --psm 3'
    data = pytesseract.image_to_data(pil_image, config=custom_config, output_type=pytesseract.Output.DICT)

    # Convert to DataFrame
    df = pd.DataFrame({
        "x1": data["left"],
        "y1": data["top"],
        "width": data["width"],
        "height": data["height"],
        "word": data["text"]
    })

    df = df[df["word"].str.strip() != ""]

    # Compute bottom-right coordinates
    df["x2"] = df["x1"] + df["width"]
    df["y2"] = df["y1"] + df["height"]

    # Filter words within horizontal margins
    df["left_margin_metric"] = df["y1"] + df["x1"]
    df["right_margin_metric"] = df["x2"] + df["y2"]
    left_margin = df.loc[df["left_margin_metric"].idxmin()]["x1"]
    right_margin = df.loc[df["right_margin_metric"].idxmax()]["x2"]
    df = df[(df["x2"] >= left_margin) & (df["x1"] <= right_margin)]

    # Save each word as a cropped image
    for idx, row in df.iterrows():
        x1, y1, x2, y2 = int(row["x1"]), int(row["y1"]), int(row["x2"]), int(row["y2"])
        word = row["word"]
        cropped = image[y1:y2, x1:x2]
        
        filename = f"{word}.png"
        save_path = os.path.join(output_folder, filename)

        cv2.imwrite(save_path, cropped)
        print(f"Saved: {save_path}")

    print(f"Completed: {image_path}")

# Walk through all images in the folder
for root, _, files in os.walk(input_folder):
    for file in files:
        if file.lower().endswith(".png"):
            full_path = os.path.join(root, file)
            process_image(full_path)

print("\n All images processed and saved in 'ocr_generated_images'")
# Out:
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\“AL.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\TEEPE.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\SES.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\SEN.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\OR.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\DON.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\ALONSO.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\PEREZ.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\DE.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\GVZMAN.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\EL.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\BVENO,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\PATRIARCHA.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\DE.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\LAS.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\INDIAS,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Arzobifpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Tyro,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Limofnero.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\mayor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Rey.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Nueftro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Sefior.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Don.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Felipe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\IV..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Grande.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Rey.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\las.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Efpafias.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Confejo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Mageftad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Iuez.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Eclefiaftico.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Ordinario.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Real.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Capilla,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Cafa,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Corte..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\‘.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\EGVNDA.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\~ee,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\(Illuftriffimo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Seftor).png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\falen.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\eftampa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\cftos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Documentos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Politicos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Morales.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\formar'vn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Principe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\perfello.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\5.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\MiniStros.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\aju=.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\(bades.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\auerfe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de[pachado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\tiempo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\breve.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\l=.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\prefion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\primera..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Helos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\atiadido.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\nueuo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\exornado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\eftampas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Emblemas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\halago.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\los.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\ojos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\pongan.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\2.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\larviftalas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\enféiiancas,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Confagréala.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Mageftad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Catolica.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\nuestro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Monarca.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\primera.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\vex.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\efie.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\libro,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\buelua.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\mejorado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fis.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Reales.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\manos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\pongo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\las.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\V.S.1..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\quien.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\admitira.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\los.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\aagrades,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\vientn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\&.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Mageftad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\merccidos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fis.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\grandes,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\conti.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\nuados.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\feruicios,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Como.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fino.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\vuiera.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\VS..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\beredado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fus.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\excellenti-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fimos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Progenitores.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\fer.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Conse.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\Bueno.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\{us.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\acciones.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\ba.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\gran-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\toa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_1_words\‘geado.png
# Completed: pdf_to_images\Mendo - Principe perfecto\Mendo - Principe perfecto_page_1.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\geado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\ferlo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\s.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\logrando.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\dignamenté.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\nueftro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Monarcba.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\gracias.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\‘en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fiuCorte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\cariio:enel.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Orbe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\toda.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\eftimacion,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\9.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\famaenla.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\pofteridad..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\El.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\es.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\comun.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\amparo,,no.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\negara.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\ferlo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\defta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\calificandola.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\leerla.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\:.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\bonrandola.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\admitirla.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\:y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\patrocin.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\repetir.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\nombre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Autor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\&.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fiw.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Mageftad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\effe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\obfequio,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fiendo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Idea.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\on.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Principe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Perfetto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\retrata.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\al-vino.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\como.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\bien.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\V.S.1,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fiendo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\efpejo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\decom.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Minifiro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\ajuftado..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Cuya.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\vida;.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\ere.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\cielo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\enla.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\mayor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\grandeza.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\bien,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\felicidad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\|.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Salamanca.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Noniembre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\15..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\1659..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Humilde.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\Capellan.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\V-S.1..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\mano.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\bela..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\ANDRES.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_2_words\MENDO..png
# Completed: pdf_to_images\Mendo - Principe perfecto\Mendo - Principe perfecto_page_2.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Ad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\aah.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\APROBACION.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Dottor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\D.Francifia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Paga,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Feijoo,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Colegial.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\det.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Colegio.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Mayor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Arxobifpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Toledo,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Cathe-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\dratico.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Prima.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Canones.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Vni-\.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\werfidad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Salamanca,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Ox.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Comifion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Illuftriffimo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Seffor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Don.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Tuan.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Perez,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Delgado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Obifpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Salamanca,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Confejo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Mageftad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\;.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Heleydocon.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\atencion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\efte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\libro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Documentos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Polici-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\cos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Morales.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\vn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Principe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Perfecto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Miniftros.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ajuftados,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eferibid.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\nueftromuy.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Reuerendo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Padre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Andres.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Mendo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Compaitia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Irsvs.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Leétor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fae.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\aqui.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Theologia,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\E(critura,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Re€tor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Colegio..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Irlandefes.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\defta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Vniuerfidad,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Calificador.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Con-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fejo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\inquificion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Suprema..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Confiefo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\midicha,por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\auerla.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\tenido.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\participar.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\noticias.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\tanta‘erudicion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\afi.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Sagrada,como.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Profana,antes.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eftampa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\las.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\co-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\municafe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\4.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\todos;.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\bienque.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\nunca.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\pueden.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\hazerfe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\vul-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\gares,por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\folicite.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\vtilidad..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Al.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Autor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\han.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\puefto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fus.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Efcritos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\primera.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Clafe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\deftos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\tiempos,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\finque.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\efte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\lugar.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\puedacontronertirfele.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\defarencion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\injufta,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\No.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ay.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\empefio.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\letras,A.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\no.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\farisfaga.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\caudal.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ventajo{o.Lo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\extraordinario,lo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\raro,{e.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\lo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\referud.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\prouidencia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\tanto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\acierto,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fenda.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eftrecha.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\haze.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\camino.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Real.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\4.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Ja.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\tarea.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\incefable.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fi.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eftudiofidad..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\No.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ay.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\rumbo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\defeubriral.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\norte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ingenio,ni.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\afpereza.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ficilitar.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\4.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fu.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\huella.Sefias.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fon.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eftasde.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\faslibros.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Expoficion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\BullasDe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Inre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Academico;De.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Ordinibus.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Militaribus.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\;.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Obras.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\alladel.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\aplaufo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\encarecido..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\En.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\efta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\metodo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\afegurade.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Cenfara,dittribuyendolas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Vireudes.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\morales.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\vp.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\Prin.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\cipe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ilacionsque.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\hafta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\en.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\variedad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fuele.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\echarfe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\menos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\confequencia..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\El.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\eftilo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ie.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\ean.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\fe-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\3.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_3_words\He.png
# Completed: pdf_to_images\Mendo - Principe perfecto\Mendo - Principe perfecto_page_3.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\riedad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\delafampto,vfaudole.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\graue,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\ponderofo,fin.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Ieencumbrelasfedacion.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\es.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\sajamuy.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\etme.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\dela.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\pradencia,quela.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\pluma.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fi.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\mas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\remontada.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\go-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\uierne.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\buelos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\al.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\pefo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\delasmaterias..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Quantos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\co-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\nocenal.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Autor,le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\han.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\oydo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\frequenteméte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\«.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\pitos,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\yle.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\han.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\venerado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\primer.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\cre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\exercicio,con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\faben.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\linea,A.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\llega.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fire.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\cia,nunca.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\inferior.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Tullio,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Demofthenes.Lavei-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Iidad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\libro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\conoce.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fin,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\pretende..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Su.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\enfeflanza.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\¢s.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Idea.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\vn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Principe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Perfetto,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fien~.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\do.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\efte.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\dalma.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\d.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\cabeza.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\cuerpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\Rept.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\bien.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\deja.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\entender,quan.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_4_words\benignas.png
# ...
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Documentos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Politicos,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\morales,cOpuetto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\P.Andres.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\[endo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Compaftia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\lefus,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Reétor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Collegio.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Irladefés.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Viiiuerfidad.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\defta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\dicha.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Ciudadsaten-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\to,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\cenfura.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Doétor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Don.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Frarcifco.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Puga,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Foc.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\cea.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Mayor.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Arzobifpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Toledo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\dicha.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Vniuerfidadyy.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Cathedratico.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Prima.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Ca-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\honesdella,confta,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\no.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\tiene.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\cofa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\alguna.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\contra.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nueftra.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fanta.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Catholica,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\buenas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\coftumbres.Dadaen.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Sala-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ianca.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\4.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\feis.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\dias.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\mesdeTulio.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\165.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\6..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\affos..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Juan.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Obifpa.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Salamanca,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Pot.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\maridado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\del.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Opilpo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ini.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Bartolome.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\FernandeX.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Me.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\5.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Licencin.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\det.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\R.P.adiguel.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Arbiza.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Provincial.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Com..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\oo).png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\patinde.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fhe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Ja.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Provincia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Caftilla,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\i.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\‘iiss.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ation.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Patina.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\‘de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\la.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Compahiia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Tefis.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\JaProuinciade.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Caftilla,por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\efpecial.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\comifion,que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ra.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ello.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\tengo.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nueftro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Padre.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Gofvvino.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\NiKel.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Prepo-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\feat.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\por.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\las.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\prefentes.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\doy.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\licencia.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\al.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\PeAndees.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ra.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Reli.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\@.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ede.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\‘Compania,y’.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\a.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\f.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\x.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\N.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Suprema,para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\qite.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\pucda.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\imprimir.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\vn.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Libto,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\hacompuctto.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\mekalui.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Prtcipe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\pete,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\7.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Minifires.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\rier.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Deck.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Polli.7.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Mirae.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\po.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\auc.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\vO,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\aprobado.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\perfonas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\grantes.y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\dodtas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nueftea.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Religion,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\ien-le.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\cometimos,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\En.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fe.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\deloqual,y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\para.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\que.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\dello.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\con-.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\2.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\damos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\eftas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nueftras.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\letras.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\firmadas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nueftro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nom.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\bre,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\y.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\(elladas.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\con.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\el.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\fello.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\nucftro.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\oficio,,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\En.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Burgos.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\a7d¢Notienbgede.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\1656,.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Miguel.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\de.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\Arbizu..png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\*.png
# Saved: ocr_generated_words\Mendo - Principe perfecto_page_5_words\APRO.png
# Completed: pdf_to_images\Mendo - Principe perfecto\Mendo - Principe perfecto_page_5.png
#
#  All images processed and saved in 'ocr_generated_images'

# %% [markdown]
# ### Batch-Correcting OCR Word Image Filenames via Transcript Matching with Levenshtein Distance
#
# This script automatically renames and organizes OCR-extracted word images by matching their filenames to words in their corresponding transcript files using fuzzy matching based on Levenshtein distance.

# %%
import os
import shutil
import Levenshtein

# Paths
ocr_image_root = "ocr_generated_words"
transcript_root = "Transcript to txt"

# Function to load words from transcript (preserving case)
def load_transcript_words(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return set(f.read().split())

# Function to find best match using Levenshtein distance
def find_best_match(word, transcript_words):
    best_match = None
    best_score = float("inf")

    for tw in transcript_words:
        score = Levenshtein.distance(word.lower(), tw.lower())
        if score < best_score:
            best_score = score
            best_match = tw

    return best_match if best_score <= len(word) * 0.4 else None  # 60% similarity threshold

# Looping over all folders in ocr_generated_images
for folder_name in os.listdir(ocr_image_root):
    input_folder = os.path.join(ocr_image_root, folder_name)

    if not os.path.isdir(input_folder):
        continue  # Skip non-folder entries

    # Attempting to find the correct transcript file
    matching_transcript = None
    for transcript_file in os.listdir(transcript_root):
        if "page_" in folder_name and "page_" in transcript_file:
            page_ref = folder_name.split("page_")[-1].split("_")[0]  # e.g., '1' from 'Buendia_page_1_words'
            if f"page_{page_ref}" in transcript_file:
                matching_transcript = os.path.join(transcript_root, transcript_file)
                break

    if not matching_transcript:
        print(f" No matching transcript found for: {folder_name}")
        continue

    # Loading transcript words
    transcript_words = load_transcript_words(matching_transcript)
    used_filenames = set()

    # Creating output folder
    corrected_folder = os.path.join(ocr_image_root, f"{folder_name}_corrected")
    os.makedirs(corrected_folder, exist_ok=True)

    # Processing each image in the folder
    for image_file in os.listdir(input_folder):
        input_image_path = os.path.join(input_folder, image_file)
        image_name, _ = os.path.splitext(image_file)

        best_match = find_best_match(image_name, transcript_words)

        if best_match:
            if best_match in used_filenames:
                print(f" Skipped duplicate: {image_file} -> {best_match}.png")
                continue

            corrected_path = os.path.join(corrected_folder, f"{best_match}.png")
            shutil.copy(input_image_path, corrected_path)
            used_filenames.add(best_match)
            print(f" Saved: {image_file} -> {corrected_path}")
        else:
            print(f" Skipped: {image_file} (no good match found)")

    print(f" Finished correcting filenames in: {folder_name}\n")

print(" All folders processed and corrected images saved.")
# Out:
#  Skipped: &.png (no good match found)
#  Skipped: (bades.png (no good match found)
#  Saved: (Illuftriffimo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Illustrissimo.png
#  Skipped: ,.png (no good match found)
#  Saved: ,por.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\por.png
#  Skipped: ..png (no good match found)
#  Skipped: 2.png (no good match found)
#  Skipped: 5.png (no good match found)
#  Saved: a.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\a.png
#  Saved: aagrades,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\agrados,.png
#  Saved: acciones.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\acciones.png
#  Saved: admitira.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\admitira.png
#  Saved: aju=.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\aju-.png
#  Saved: ALONSO.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\ALONSO.png
#  Saved: Arzobifpo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Arzobispo.png
#  Saved: atiadido.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\añadido.png
#  Saved: auerfe.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\averse.png
#  Skipped: ba.png (no good match found)
#  Saved: beredado.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\heredado.png
#  Saved: breve.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\breve.png
#  Saved: buelua.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\buelva.png
#  Saved: Bueno.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Bueno,.png
#  Skipped duplicate: BVENO,.png -> Bueno,.png
#  Saved: Cafa,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Casa,.png
#  Saved: Capilla,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Capilla,.png
#  Saved: Catolica.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Catolica.png
#  Saved: cftos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\estos.png
#  Saved: Como.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Como.png
#  Saved: con.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\con.png
#  Skipped: ConfagrÃ©ala.png (no good match found)
#  Saved: Confejo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Consejo.png
#  Skipped duplicate: Conse.png -> Consejo.png
#  Saved: conti.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\conti-.png
#  Saved: Corte..png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Corte.png
#  Saved: DE.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\DE.png
#  Saved: del.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\del.png
#  Saved: de[pachado.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\despachado.png
#  Saved: Documentos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Documentos.png
#  Saved: DON.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Don.png
#  Saved: Eclefiaftico.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Eclesiastico.png
#  Skipped: efie.png (no good match found)
#  Skipped: Efpafias.png (no good match found)
#  Saved: eftampa.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\estampa.png
#  Saved: eftampas.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\estampas.png
#  Saved: EGVNDA.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\SEGUNDA.png
#  Saved: EL.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\el.png
#  Saved: Emblemas.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Emblemas,.png
#  Saved: en.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\en.png
#  Skipped: enfÃ©iiancas,.png (no good match found)
#  Saved: excellenti-.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\excellenti-.png
#  Saved: exornado.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\exornado.png
#  Skipped: fa.png (no good match found)
#  Saved: falen.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Salen.png
#  Saved: Felipe.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Felipe.png
#  Saved: fer.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\ser.png
#  Saved: feruicios,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Servicios.png
#  Saved: fimos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\simos.png
#  Skipped: fino.png (no good match found)
#  Skipped: fis.png (no good match found)
#  Saved: formar'vn.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\formar.png
#  Skipped: fu.png (no good match found)
#  Saved: fus.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\sus.png
#  Saved: gran-.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\gran-.png
#  Saved: Grande.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Grande.png
#  Saved: grandes,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\grandes,.png
#  Saved: GVZMAN.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\GVZMAN.png
#  Saved: halago.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\halago.png
#  Saved: Helos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Helos.png
#  Saved: INDIAS,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\INDIAS.png
#  Saved: Iuez.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Iuez.png
#  Saved: IV..png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\IV.png
#  Skipped: l=.png (no good match found)
#  Saved: la.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\la.png
#  Skipped: larviftalas.png (no good match found)
#  Saved: LAS.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\las.png
#  Saved: le.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\le.png
#  Saved: libro,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\libro,.png
#  Saved: Limofnero.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Limosnero.png
#  Saved: los.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\los.png
#  Saved: Mageftad.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Magestad.png
#  Saved: manos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\manos,.png
#  Saved: mas.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\mas.png
#  Saved: mayor.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\mayor.png
#  Saved: mejorado.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\mejorado.png
#  Saved: merccidos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\merecidos.png
#  Saved: MiniStros.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Ministros.png
#  Saved: Monarca.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Monarca.png
#  Saved: Morales.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Morales.png
#  Saved: nuados.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\nuados.png
#  Saved: Nueftro.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\nuestro.png
#  Skipped duplicate: nuestro.png -> nuestro.png
#  Saved: nueuo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\nuevo,.png
#  Saved: ojos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\ojos.png
#  Skipped: OR.png (no good match found)
#  Saved: Ordinario.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Ordinario.png
#  Saved: para.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\para.png
#  Saved: PATRIARCHA.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\PATRIARCHA.png
#  Saved: PEREZ.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\PEREZ.png
#  Saved: perfello.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\perfecto,.png
#  Saved: Politicos.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Politicos,.png
#  Saved: pongan.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\pongan.png
#  Saved: pongo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\pongo.png
#  Saved: prefion.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\presion.png
#  Saved: primera..png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\primera.png
#  Skipped duplicate: primera.png -> primera.png
#  Saved: Principe.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Principe.png
#  Saved: Progenitores.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Progenitores.png
#  Saved: que.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\que.png
#  Saved: quien.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\quien.png
#  Saved: Real.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Real.png
#  Saved: Reales.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Reales.png
#  Saved: Rey.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Rey.png
#  Saved: Sefior.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Señor.png
#  Skipped: Seftor).png (no good match found)
#  Skipped duplicate: SEN.png -> en.png
#  Skipped duplicate: SES.png -> ser.png
#  Skipped: TEEPE.png (no good match found)
#  Saved: tiempo.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\tiempo.png
#  Skipped: toa.png (no good match found)
#  Saved: Tyro,.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\Tyro,.png
#  Skipped: V.S.1..png (no good match found)
#  Saved: vex.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\vez.png
#  Saved: vientn.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\tienen.png
#  Skipped: VS..png (no good match found)
#  Saved: vuiera.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\vuiera.png
#  Saved: y.png -> ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected\y.png
#  Skipped duplicate: {us.png -> sus.png
#  Skipped: ~ee,.png (no good match found)
#  Skipped: â€œAL.png (no good match found)
#  Skipped: â€˜.png (no good match found)
#  Skipped: â€˜geado.png (no good match found)
#  Finished correcting filenames in: Mendo - Principe perfecto_page_1_words
#
#  Skipped: &.png (no good match found)
#  Skipped: ,.png (no good match found)
#  Saved: 15..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\15.png
#  Saved: 1659..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\1659.png
#  Skipped: 9.png (no good match found)
#  Saved: a.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\a.png
#  Saved: admitirla.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\admitirla.png
#  Saved: ajuftado..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\ajustado.png
#  Skipped: al-vino.png (no good match found)
#  Saved: amparo,,no.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\amparo,.png
#  Saved: ANDRES.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\ANDRES.png
#  Saved: Autor.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Autor.png
#  Saved: bela..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\besa.png
#  Saved: bien,.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\bien,.png
#  Saved: bien.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\bien.png
#  Saved: bonrandola.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\honrandola.png
#  Saved: calificandola.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\calificandola.png
#  Saved: Capellan.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Capellan.png
#  Saved: cariio -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\cariño.png
#  Saved: cielo.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\cielo.png
#  Saved: como.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\como.png
#  Saved: comun.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\comun.png
#  Saved: con.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\con.png
#  Saved: Cuya.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Cuya.png
#  Saved: de.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\de.png
#  Skipped: decom.png (no good match found)
#  Saved: defta.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\desta.png
#  Saved: dignamentÃ©.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\dignamente.png
#  Skipped: effe.png (no good match found)
#  Saved: efpejo.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\espejo.png
#  Saved: eftimacion,.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\estimacion,.png
#  Saved: el.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\el.png
#  Saved: en.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\en.png
#  Skipped: enla.png (no good match found)
#  Skipped: ere.png (no good match found)
#  Saved: es.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\es.png
#  Skipped: famaenla.png (no good match found)
#  Skipped: fe.png (no good match found)
#  Saved: felicidad.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\felicidad.png
#  Saved: ferlo.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\serlo.png
#  Skipped: fia.png (no good match found)
#  Saved: fiendo.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\siendo.png
#  Saved: fiuCorte.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Corte.png
#  Skipped: fiw.png (no good match found)
#  Skipped: fu.png (no good match found)
#  Saved: geado.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\geado.png
#  Saved: gracias.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\gracia.png
#  Saved: grandeza.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\grandeza.png
#  Saved: Humilde.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Humilde.png
#  Saved: Idea.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Idea.png
#  Saved: la.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\la.png
#  Saved: le.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\le.png
#  Saved: leerla.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\leerla.png
#  Saved: logrando.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\logrando.png
#  Saved: Mageftad.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Magestad.png
#  Saved: mano.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\mano.png
#  Saved: mayor.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\mayor.png
#  Saved: MENDO..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\MENDO.png
#  Saved: Minifiro.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Ministro.png
#  Saved: Monarcba.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Monarcha.png
#  Saved: negara.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\negará.png
#  Saved: nombre.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\nombre.png
#  Saved: Noniembre.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Nouiembre.png
#  Saved: nueftro.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\nuestro.png
#  Saved: obfequio,.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\obsequio,.png
#  Skipped: on.png (no good match found)
#  Saved: Orbe.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Orbe.png
#  Saved: para.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\para.png
#  Skipped: patrocin.png (no good match found)
#  Saved: Perfetto.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Perfecto,.png
#  Saved: pofteridad..png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\posteridad.png
#  Saved: Principe.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Principe.png
#  Saved: que.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\que.png
#  Saved: repetir.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\repetir.png
#  Saved: retrata.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\retrata.png
#  Saved: s.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\S.png
#  Saved: Salamanca.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\Salamanca.png
#  Saved: toda.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\todo.png
#  Skipped: V-S.1..png (no good match found)
#  Skipped: V.S.1,.png (no good match found)
#  Saved: vida;.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\vida.png
#  Saved: y.png -> ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected\y.png
#  Skipped: â€˜en.png (no good match found)
#  Finished correcting filenames in: Mendo - Principe perfecto_page_2_words
#
#  Skipped: ,.png (no good match found)
#  Skipped: 3.png (no good match found)
#  Skipped: 4.png (no good match found)
#  Saved: ;.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\;.png
#  Saved: a.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\a.png
#  Skipped: aah.png (no good match found)
#  Saved: Academico;De.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Academico.png
#  Saved: acierto,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\acierto,.png
#  Skipped: Ad.png (no good match found)
#  Saved: afegurade.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\asegura.png
#  Saved: afi.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\asi.png
#  Saved: afpereza.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\aspereza.png
#  Saved: ajuftados,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\ajustados,.png
#  Saved: Al.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Al.png
#  Skipped: alladel.png (no good match found)
#  Saved: Andres.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Andres.png
#  Saved: aplaufo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\aplauso.png
#  Saved: APROBACION.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\APROBACION.png
#  Saved: aqui.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\aqui.png
#  Saved: Arxobifpo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Arzobispo.png
#  Saved: atencion.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\atencion.png
#  Saved: auerla.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\auerla.png
#  Saved: Autor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Autor.png
#  Saved: ay.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\ay.png
#  Saved: bienque.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\bienque.png
#  Saved: BullasDe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Bulla.png
#  Saved: Calificador.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Calificado.png
#  Saved: camino.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\comino.png
#  Saved: Canones.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Canones.png
#  Saved: Cathe-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Cath-.png
#  Saved: caudal.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\caudal.png
#  Skipped: Cenfara,dittribuyendolas.png (no good match found)
#  Saved: cipe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\cipe.png
#  Saved: Clafe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Clase.png
#  Saved: co-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\co-.png
#  Saved: Colegial.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Colegial.png
#  Saved: Colegio..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Colegio.png
#  Skipped duplicate: Colegio.png -> Colegio.png
#  Saved: Comifion.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Comision.png
#  Saved: Compaitia.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Comañia.png
#  Saved: Con-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Con-.png
#  Saved: con.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\con.png
#  Saved: Confejo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Consejo.png
#  Saved: confequencia..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\consequencia.png
#  Saved: Confiefo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Confieso.png
#  Skipped duplicate: cos.png -> co-.png
#  Skipped: D.Francifia.png (no good match found)
#  Saved: de.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\de.png
#  Saved: defarencion.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\desatencion.png
#  Saved: defeubriral.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\descubrir.png
#  Saved: defta.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\desta.png
#  Saved: deftos.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\destos.png
#  Saved: Del.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\del.png
#  Saved: Delgado.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Delgado.png
#  Skipped duplicate: det.png -> de.png
#  Saved: Documentos.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Documentos.png
#  Saved: Don.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Don.png
#  Saved: Dottor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Doctor.png
#  Saved: dratico.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\dratico.png
#  Saved: E(critura,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Escritura,.png
#  Saved: ean.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\en.png
#  Saved: echarfe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\echarse.png
#  Saved: Efcritos.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Escritos.png
#  Saved: eferibid.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\escribió.png
#  Saved: efta.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\esta.png
#  Saved: eftampa.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\estampa.png
#  Skipped: eftasde.png (no good match found)
#  Saved: efte.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\este.png
#  Saved: eftilo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\estilo.png
#  Saved: eftrecha.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\estrecha.png
#  Saved: eftudiofidad..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\estudiosidad.png
#  Saved: el.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\el.png
#  Saved: empefio.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\empeño.png
#  Skipped duplicate: en.png -> en.png
#  Saved: encarecido..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\encarecido.png
#  Saved: Expoficion.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Exposicion.png
#  Saved: extraordinario,lo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\extraordinario,.png
#  Skipped: fa.png (no good match found)
#  Saved: fae.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\fue.png
#  Saved: farisfaga.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\satisfaga.png
#  Saved: faslibros.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\libros.png
#  Saved: fe-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\se-.png
#  Skipped: fe.png (no good match found)
#  Saved: Feijoo,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Feijoo,.png
#  Saved: fejo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\sejo.png
#  Saved: fenda.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\senda.png
#  Skipped: fi.png (no good match found)
#  Saved: ficilitar.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\facilitar.png
#  Skipped duplicate: finque.png -> bienque.png
#  Skipped: fn.png (no good match found)
#  Saved: folicite.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\solicite.png
#  Skipped duplicate: fon.png -> Don.png
#  Skipped: fu.png (no good match found)
#  Saved: fuele.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\suele.png
#  Skipped duplicate: fus.png -> fue.png
#  Saved: gares,por.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\gares,.png
#  Saved: hafta.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\hasta.png
#  Saved: han.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\han.png
#  Saved: haze.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\haze.png
#  Saved: hazerfe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\hazerse.png
#  Saved: He.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\He.png
#  Skipped: Heleydocon.png (no good match found)
#  Skipped: huella.Sefias.png (no good match found)
#  Skipped: ie.png (no good match found)
#  Saved: ilacionsque.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\ilacion.png
#  Saved: Illuftriffimo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Illustrissimo.png
#  Saved: incefable.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\incesable.png
#  Saved: ingenio,ni.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\ingenio,.png
#  Saved: injufta,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\injusta.png
#  Saved: inquificion.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Inquisicion.png
#  Saved: Inre.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Iure.png
#  Saved: Irlandefes.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Irlandeses.png
#  Saved: Irsvs.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\IESVS,.png
#  Skipped: Ja.png (no good match found)
#  Saved: la.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\la.png
#  Saved: las.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\las.png
#  Saved: le.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\le.png
#  Saved: letras,A.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\letras,.png
#  Saved: LeÃ©tor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Lector.png
#  Saved: libro.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\libro.png
#  Saved: lo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Lo.png
#  Saved: lugar.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\lugar.png
#  Saved: Mageftad.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Magestad.png
#  Saved: mas.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\mas.png
#  Saved: Mayor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Mayor.png
#  Saved: Mendo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Mendo.png
#  Saved: menos.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\menos.png
#  Saved: metodo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\metodo.png
#  Skipped: midicha,por.png (no good match found)
#  Saved: Militaribus.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Militaribus.png
#  Saved: Miniftros.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Ministros.png
#  Saved: Morales.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Morales.png
#  Saved: municafe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\municarse.png
#  Saved: No.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\no.png
#  Saved: norte.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\norte.png
#  Saved: noticias.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\noticias.png
#  Saved: nueftromuy.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\nuestro.png
#  Saved: nunca.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\nunca.png
#  Saved: Obifpo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Obispo.png
#  Saved: Obras.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Obras.png
#  Saved: Ordinibus.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Ordinibus.png
#  Skipped: Ox.png (no good match found)
#  Saved: Padre.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Padre.png
#  Saved: Paga,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Puga,.png
#  Saved: para.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\para.png
#  Saved: participar.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\participar.png
#  Saved: Perez,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Perez.png
#  Saved: Perfecto.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\PErfecto,.png
#  Saved: Polici-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Politi-.png
#  Saved: por.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\por.png
#  Saved: Prima.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Prima.png
#  Saved: primera.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\primera.png
#  Saved: Prin.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Prin-.png
#  Saved: Principe.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Principe.png
#  Saved: Profana,antes.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Profana,.png
#  Saved: prouidencia.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\providencia.png
#  Saved: puedacontronertirfele.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\controvertirsele.png
#  Saved: pueden.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\pueden.png
#  Saved: puefto.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\puesto.png
#  Saved: que.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\que.png
#  Saved: raro,{e.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\raro,.png
#  Saved: Real.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Real.png
#  Skipped: referud.png (no good match found)
#  Saved: Reuerendo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Reverendo.png
#  Saved: Reâ‚¬tor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Rector.png
#  Saved: rumbo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\rumbo.png
#  Saved: Sagrada,como.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Sagrada,.png
#  Saved: Salamanca,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Salamanca,.png
#  Saved: Seffor.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Señor.png
#  Saved: Suprema..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Suprema.png
#  Skipped: tantaâ€˜erudicion.png (no good match found)
#  Saved: tanto.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\tanto.png
#  Saved: tarea.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\tarea.png
#  Saved: tenido.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\tenido.png
#  Saved: Theologia,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Theologia,.png
#  Saved: tiempos,.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\tiempo,.png
#  Saved: todos;.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\todos.png
#  Saved: Toledo,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Toledo,.png
#  Saved: Tuan.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Iuan.png
#  Saved: variedad.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\variedad.png
#  Saved: ventajo{o.Lo.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\ventajoso.png
#  Saved: Vireudes.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Virtudes.png
#  Saved: vn.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\vn.png
#  Saved: Vniuerfidad,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\Vniversidad,.png
#  Skipped: vp.png (no good match found)
#  Saved: vtilidad..png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\vtilidad.png
#  Saved: vul-.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\vul-.png
#  Saved: werfidad.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\versidad.png
#  Saved: y.png -> ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected\y.png
#  Finished correcting filenames in: Mendo - Principe perfecto_page_3_words
#
#  Skipped: ,.png (no good match found)
#  Skipped: ,prefriÃ©ia.png (no good match found)
#  Skipped: ..png (no good match found)
#  Skipped: 2nd.png (no good match found)
#  Skipped: 5.png (no good match found)
#  Saved: a.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\a.png
#  Saved: abedecer..png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\obedecer.png
#  Saved: acie,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\acie,.png
#  Saved: ad.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\ad.png
#  Saved: adegerunt.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\adegerunt,.png
#  Saved: afi.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\asi.png
#  Saved: al.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\al.png
#  Saved: alias.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\las.png
#  Skipped: an.png (no good match found)
#  Skipped: anguaneipfiumi.png (no good match found)
#  Saved: Anon.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\non.png
#  Saved: aprender,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\aprender,.png
#  Saved: Ardua.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Ardua.png
#  Saved: Autor,fon.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Autor,.png
#  Skipped duplicate: Autor,le.png -> Autor,.png
#  Saved: Bafilio.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Basilio.png
#  Skipped: Baleeiaca.png (no good match found)
#  Saved: ballo,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\hallo.png
#  Saved: benignas.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\benignas.png
#  Saved: bien.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\bien.png
#  Saved: Brande.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\grande.png
#  Saved: buelos.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\buelos.png
#  Saved: cabeza.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\cabeza.png
#  Skipped duplicate: calla.png -> hallo.png
#  Saved: caruerunt..png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\caruerunt.png
#  Saved: caufara.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\causara.png
#  Skipped: cebu.png (no good match found)
#  Skipped: ceubis.png (no good match found)
#  Skipped: Chrifti.png (no good match found)
#  Skipped: cia,nunca.png (no good match found)
#  Saved: co-.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\co-.png
#  Skipped: co.png (no good match found)
#  Saved: coftumbres.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\costumbres.png
#  Saved: como.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\como.png
#  Saved: comprehenditsut'.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\comprehendit,.png
#  Saved: con.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Con.png
#  Saved: conduce,para.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\conduce,.png
#  Saved: conoce.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\conoce.png
#  Saved: contendentibus.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\contendentibus.png
#  Skipped: conteniohadr,.png (no good match found)
#  Saved: corregidas.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\corregidas.png
#  Skipped: cre.png (no good match found)
#  Saved: crudicion.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\erudicion.png
#  Saved: cuerpo.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\cuerpo.png
#  Skipped: d.png (no good match found)
#  Saved: dalma.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\alma,.png
#  Saved: de.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\de.png
#  Saved: defmiayadala.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\desmayada.png
#  Saved: deja.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\deja.png
#  Saved: dejar.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\dejar.png
#  Saved: del.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\del.png
#  Skipped duplicate: dela.png -> deja.png
#  Skipped: delafampto,vfaudole.png (no good match found)
#  Skipped: delasmaterias..png (no good match found)
#  Skipped: Demofthenes.Lavei-.png (no good match found)
#  Saved: desfera.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\esfera.png
#  Saved: deza.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\deza.png
#  Saved: dezir.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\dezir.png
#  Saved: difeipline.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\disciplina.png
#  Saved: dijo.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\dijo.png
#  Saved: do.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\do.png
#  Skipped: ee.png (no good match found)
#  Saved: ees.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\es.png
#  Saved: efimerada.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\esmerada.png
#  Saved: efta.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\esta.png
#  Saved: efte.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\este.png
#  Skipped: eftosaduertidas.png (no good match found)
#  Skipped: egies.png (no good match found)
#  Saved: el.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\el.png
#  Skipped: empre{aes,animar.png (no good match found)
#  Saved: en..png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\en.png
#  Skipped duplicate: en.png -> en.png
#  Saved: enfeflanza.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\enseñanza.png
#  Skipped duplicate: enfeiianza.png -> enseñanza.png
#  Saved: entender,quan.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\entender,.png
#  Skipped duplicate: es.png -> es.png
#  Skipped: etme.png (no good match found)
#  Saved: euenit.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\euenit,.png
#  Saved: excellent,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\excellentia,.png
#  Saved: exercicio,con.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\exercicio,.png
#  Saved: Exiffimare.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Existimare.png
#  Skipped: fa.png (no good match found)
#  Saved: faben.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\saben.png
#  Saved: fas.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\fas.png
#  Skipped: fe.png (no good match found)
#  Saved: fed.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\sed.png
#  Saved: ferenum.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\serenum.png
#  Skipped: fi.png (no good match found)
#  Skipped duplicate: fien~.png -> bien.png
#  Saved: fin,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\fin,.png
#  Saved: fingulas.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Singulas,.png
#  Saved: fiqui.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\qui.png
#  Skipped: fire.png (no good match found)
#  Saved: fit.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\sit.png
#  Saved: frequentemÃ©te.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\frequentemente.png
#  Skipped: fu.png (no good match found)
#  Saved: fucultate.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\facultate.png
#  Saved: fuele.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\suele.png
#  Skipped: fuexemplo.Con.png (no good match found)
#  Saved: fulger.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\fulgor.png
#  Saved: fummum.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Summum.png
#  Saved: genus..png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\genus.png
#  Saved: go-.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\qo-.png
#  Saved: grandecida.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\grandecida.png
#  Saved: graue,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\grave,.png
#  Skipped: Grin.png (no good match found)
#  Saved: han.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\han.png
#  Skipped duplicate: hes.png -> es.png
#  Saved: Hiftorica,.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Historica,.png
#  Saved: Idea.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\idea.png
#  Skipped: ieee.png (no good match found)
#  Skipped: Ieencumbrelasfedacion.png (no good match found)
#  Saved: Iidad.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\lidad.png
#  Saved: in.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\in.png
#  Saved: inferior.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\inferior.png
#  Saved: influÃ©cias.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\influencias.png
#  Saved: inguirentem.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\inquirentem.png
#  Saved: inuitat...png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\inuitat.png
#  Saved: iutuentem.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\intuentem.png
#  Skipped: Jusnam.png (no good match found)
#  Saved: la.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\la.png
#  Skipped: lade.png (no good match found)
#  Saved: lagran-_.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\gran-.png
#  Skipped duplicate: las.png -> las.png
#  Skipped: li.png (no good match found)
#  Saved: libro.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\libre.png
#  Saved: ligion.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\Religion.png
#  Saved: linea,A.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\linea,.png
#  Saved: llega.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\llega.png
#  Saved: los.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\los.png
#  Saved: luces..png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\luces.png
#  Saved: lumen.png -> ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected\lumen.png
# ...
#  Skipped duplicate: Arbizu..png -> Arbizu.png
#  Saved: Arzobifpo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Arzobispo.png
#  Skipped: ation.png (no good match found)
#  Skipped: auc.png (no good match found)
#  Skipped: ay.png (no good match found)
#  Saved: Bartolome.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Bartolome.png
#  Saved: bre,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\bre,.png
#  Saved: buenas.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\buenas.png
#  Saved: Burgos.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Burgos.png
#  Saved: Ca-.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Ca-.png
#  Saved: Caftilla,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Castilla,.png
#  Skipped duplicate: Caftilla,por.png -> Castilla,.png
#  Saved: Cathedratico.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Cathedratico.png
#  Saved: Catholica,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Catholica,.png
#  Skipped duplicate: Catholica,y.png -> Catholica,.png
#  Skipped: cea.png (no good match found)
#  Saved: cenfura.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\censura.png
#  Skipped: Ciudadsaten-.png (no good match found)
#  Saved: cofa.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\cosa.png
#  Skipped: coftumbres.Dadaen.png (no good match found)
#  Saved: Collegio.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Collegio.png
#  Saved: Com..png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Com-.png
#  Saved: cometimos,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\cometimos.png
#  Saved: comifion,que.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\comision,.png
#  Saved: Compaftia.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Compañia.png
#  Skipped duplicate: Compahiia.png -> Compañia.png
#  Saved: con-.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\con-.png
#  Saved: con.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\con.png
#  Saved: Conejo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Consejo.png
#  Saved: conque.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\conque.png
#  Saved: contra.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\contra.png
#  Saved: damos.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\damos.png
#  Saved: darfele.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\darsele.png
#  Saved: de-.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\de-.png
#  Saved: de.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\de.png
#  Saved: debe.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\debe.png
#  Skipped: Deck.png (no good match found)
#  Saved: defta.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\desta.png
#  Saved: del.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\del.png
#  Saved: Delgado.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Delgado.png
#  Saved: dello.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\dello.png
#  Skipped: deloqual,y.png (no good match found)
#  Skipped duplicate: det.png -> de.png
#  Saved: dias.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\dias.png
#  Saved: dicha.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\dicha.png
#  Saved: Dios,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Dios,.png
#  Saved: Documentos.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Documentos.png
#  Saved: dodtas.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\doctas.png
#  Saved: Don.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Don.png
#  Saved: Dotter.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Doctor.png
#  Saved: doy.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\doy.png
#  Skipped duplicate: DoÃ©tor.png -> Doctor.png
#  Skipped duplicate: ede.png -> de.png
#  Saved: efpecial.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\especial.png
#  Saved: eftas.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\estas.png
#  Saved: efte.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\este.png
#  Saved: el.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\el.png
#  Saved: elLibro.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\libro.png
#  Saved: ello.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\ello.png
#  Saved: en.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\en.png
#  Saved: enlascoftumbres.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\costumbres.png
#  Skipped: ewralfe..png (no good match found)
#  Skipped: f.png (no good match found)
#  Saved: fanca.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\manca.png
#  Saved: fanta.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\santa.png
#  Saved: fe.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\fe.png
#  Skipped: feat.png (no good match found)
#  Saved: Feijoo..png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Feijoo.png
#  Saved: feis.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\seis.png
#  Saved: fello.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\sello.png
#  Saved: FernandeX.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Fernandez.png
#  Skipped duplicate: fhe.png -> fe.png
#  Saved: firmadas.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\firmadas.png
#  Skipped: Foc.png (no good match found)
#  Saved: Francifie.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Francisco.png
#  Skipped duplicate: Frarcifco.png -> Francisco.png
#  Saved: fta.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\sta.png
#  Skipped: fu.png (no good match found)
#  Skipped duplicate: gde.png -> de.png
#  Saved: Gofvvino.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Gosvvino.png
#  Saved: graciade.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\gracia.png
#  Skipped: grantes.y.png (no good match found)
#  Skipped: hacompuctto.png (no good match found)
#  Skipped: honesdella,confta,.png (no good match found)
#  Skipped: i.png (no good match found)
#  Skipped duplicate: ianca.png -> manca.png
#  Saved: ideatur.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\videatur.png
#  Skipped: ien-le.png (no good match found)
#  Saved: imprimir.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\imprimir.png
#  Saved: ini.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\ni.png
#  Saved: inticulado.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\intitulado.png
#  Saved: IrladefÃ©s.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Irlandeses.png
#  Skipped: IuanPerez.png (no good match found)
#  Skipped: Ja.png (no good match found)
#  Saved: JaProuinciade.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Prouincial.png
#  Saved: Juan.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Iuan.png
#  Saved: la.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\la.png
#  Saved: las.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\las.png
#  Saved: lefus,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Iesus,.png
#  Saved: letras.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\letras.png
#  Skipped duplicate: libro.png -> libro.png
#  Saved: Libto,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Libro,.png
#  Saved: licencia,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\licencia,.png
#  Skipped duplicate: licencia,que.png -> licencia,.png
#  Saved: LICENCIA.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\licencia.png
#  Skipped duplicate: Licencin.png -> licencia.png
#  Saved: lo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\lo.png
#  Skipped: Mageftad,8cc.Por.png (no good match found)
#  Saved: maridado.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\mandato.png
#  Saved: Mayor.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Mayor.png
#  Skipped: Me.png (no good match found)
#  Skipped: mekalui.png (no good match found)
#  Skipped: mesdeTulio.png (no good match found)
#  Saved: mi.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\mi.png
#  Skipped: Migotde.png (no good match found)
#  Saved: Miguel.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Miguel.png
#  Saved: Minifires.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Ministros.png
#  Saved: Mirae.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\moral.png
#  Skipped duplicate: moral.png -> moral.png
#  Skipped: morales,cOpuetto.png (no good match found)
#  Skipped: N.png (no good match found)
#  Skipped duplicate: ni.png -> ni.png
#  Saved: NiKel.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\NiKel.png
#  Saved: No.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\no.png
#  Skipped duplicate: nom.png -> no.png
#  Skipped duplicate: non.png -> Don.png
#  Skipped: Nostoca,damos.png (no good match found)
#  Saved: nucftro.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\nuestro.png
#  Saved: nueftea.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\nuestra.png
#  Skipped duplicate: nueftra.png -> nuestra.png
#  Saved: nueftras.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\nuestras.png
#  Skipped duplicate: nueftro.png -> nuestro.png
#  Skipped duplicate: nue{tra.png -> nuestra.png
#  Saved: Obifpa.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Obispo.png
#  Skipped duplicate: Obifpo.png -> Obispo.png
#  Saved: oficio,,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\oficio.png
#  Skipped: oo).png (no good match found)
#  Skipped duplicate: Opilpo.png -> Obispo.png
#  Saved: ORDINARIO..png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\ORDINARIO.png
#  Saved: P.Andres.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Andres.png
#  Saved: Padre.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Padre.png
#  Saved: para.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\para.png
#  Saved: Patina.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\pañia.png
#  Skipped: patinde.png (no good match found)
#  Skipped duplicate: PeAndees.png -> Andres.png
#  Saved: Perfectoy.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Perfecto,.png
#  Saved: perfonas.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\personas.png
#  Saved: pete,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\ste,.png
#  Saved: pide..png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\pide.png
#  Skipped: po.png (no good match found)
#  Saved: Politicos,y.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Politicos,.png
#  Skipped: Polli.7.png (no good match found)
#  Saved: por.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\por.png
#  Skipped duplicate: Pot.png -> por.png
#  Skipped: prefente,porlo.png (no good match found)
#  Saved: prefentes.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\presentes.png
#  Saved: Prepo-.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Prepo-.png
#  Saved: Prima.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Prima.png
#  Saved: Principe.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Principe.png
#  Saved: Provincia.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Prouincia.png
#  Skipped duplicate: Provincial.png -> Prouincial.png
#  Skipped duplicate: Prtcipe.png -> Principe.png
#  Saved: pucda.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\pueda.png
#  Skipped duplicate: pueda.png -> pueda.png
#  Saved: Puga,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Puga,.png
#  Skipped duplicate: Pugay.png -> Puga,.png
#  Skipped: qite.png (no good match found)
#  Saved: que.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\que.png
#  Skipped: quedefdigade.png (no good match found)
#  Skipped: R.P.adiguel.png (no good match found)
#  Skipped: ra.png (no good match found)
#  Skipped: Reli.png (no good match found)
#  Saved: Religion,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Religion,.png
#  Saved: ReÃ©tor.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Rector.png
#  Skipped: rier.png (no good match found)
#  Saved: Sala-.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Sala-.png
#  Saved: Salamanca,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Salamanca,.png
#  Skipped duplicate: Salamanca,del.png -> Salamanca,.png
#  Skipped duplicate: SantaFe.png -> santa.png
#  Skipped: Sapancarlulia.png (no good match found)
#  Saved: Sede.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Sede.png
#  Saved: Suprema,para.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Suprema,.png
#  Skipped duplicate: Tefis.png -> seis.png
#  Saved: tengo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\tengo.png
#  Saved: tiene.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\tiene.png
#  Saved: to,.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\to,.png
#  Saved: todo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\todo.png
#  Saved: Toledo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Toledo.png
#  Saved: Viiiuerfidad.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Vniversidad.png
#  Saved: vn.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\vn.png
#  Skipped duplicate: Vniuerfidadyy.png -> Vniversidad.png
#  Skipped duplicate: vO,.png -> to,.png
#  Skipped: x.png (no good match found)
#  Saved: y.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\y.png
#  Saved: [endo.png -> ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected\Mendo.png
#  Skipped: _Â».png (no good match found)
#  Skipped: â€˜Compania,yâ€™.png (no good match found)
#  Skipped: â€˜de.png (no good match found)
#  Skipped: â€˜iiss.png (no good match found)
#  Skipped: â€˜On.png (no good match found)
#  Finished correcting filenames in: Mendo - Principe perfecto_page_5_words
#
#  All folders processed and corrected images saved.

# %% [markdown]
# ### Evaluating GAN-Generated Word Images Against OCR Ground Truth Using MSE and SSIM
#
# This script quantitatively and visually evaluates the quality of GAN-generated word images by comparing them with corresponding OCR-cropped originals using Mean Squared Error (MSE) and Structural Similarity Index (SSIM).

# %%
import random

# Root folders
ocr_dir_root = "ocr_generated_words"
gan_dir_root = "gan_generated_words"

# Image preprocessing constants
target_height = 64
max_width = 300

def load_and_preprocess(image_path):
    img = Image.open(image_path).convert('L')
    w, h = img.size
    new_w = int((target_height / h) * w)
    img = img.resize((new_w, target_height), Image.LANCZOS)

    if new_w < max_width:
        pad_left = (max_width - new_w) // 2
        pad_right = max_width - new_w - pad_left
        img = ImageOps.expand(img, (pad_left, 0, pad_right, 0), fill=255)
    else:
        img = img.crop((0, 0, max_width, target_height))

    img_array = np.array(img).astype(np.float32) / 255.0
    return tf.convert_to_tensor(img_array)[..., tf.newaxis]

def compute_metrics(original_img, generated_img):
    mse = tf.reduce_mean(tf.square(original_img - generated_img)).numpy()
    ssim = tf.image.ssim(original_img, generated_img, max_val=1.0).numpy()
    return mse, ssim

def show_example(filename, orig_img, gen_img, mse, ssim):
    fig, axs = plt.subplots(1, 2, figsize=(8, 3))
    axs[0].imshow(tf.squeeze(orig_img), cmap='gray')
    axs[0].set_title(f"Original: {filename}")
    axs[1].imshow(tf.squeeze(gen_img), cmap='gray')
    axs[1].set_title(f"Generated\nMSE: {mse:.2f}, SSIM: {ssim:.2f}")
    for ax in axs:
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# Global aggregates
global_mse_total = 0
global_ssim_total = 0
global_count = 0
all_examples = []  # For 5 random examples

# Processing each GAN folder
for gan_folder in os.listdir(gan_dir_root):
    gan_folder_path = os.path.join(gan_dir_root, gan_folder)
    if not os.path.isdir(gan_folder_path):
        continue

    matching_ocr_folder = None
    if "page_" in gan_folder:
        page_ref = gan_folder.split("page_")[-1].split("_")[0]
        for ocr_folder in os.listdir(ocr_dir_root):
            if f"page_{page_ref}" in ocr_folder and "corrected" in ocr_folder:
                matching_ocr_folder = os.path.join(ocr_dir_root, ocr_folder)
                break

    if not matching_ocr_folder:
        print(f" No matching corrected OCR folder found for: {gan_folder}")
        continue

    print(f"\n Comparing:\n   GAN:  {gan_folder_path}\n   OCR:  {matching_ocr_folder}")
    results = []
    local_mse_total = 0
    local_ssim_total = 0
    local_count = 0

    for filename in os.listdir(matching_ocr_folder):
        if not filename.lower().endswith(".png") or 's' in filename.lower():
            continue

        ocr_img_path = os.path.join(matching_ocr_folder, filename)
        gan_img_path = os.path.join(gan_folder_path, filename)

        if not os.path.exists(gan_img_path):
            print(f" Skipping {filename}: no GAN counterpart.")
            continue

        try:
            ocr_img = load_and_preprocess(ocr_img_path)
            gan_img = load_and_preprocess(gan_img_path)
        except Exception as e:
            print(f" Error loading {filename}: {e}")
            continue

        mse, ssim = compute_metrics(ocr_img, gan_img)
        results.append((filename, mse, ssim))

        # Adding for random display
        all_examples.append((filename, ocr_img, gan_img, mse, ssim))

        local_mse_total += mse
        local_ssim_total += ssim
        local_count += 1

        global_mse_total += mse
        global_ssim_total += ssim
        global_count += 1
        
    if local_count > 0:
        avg_mse = local_mse_total / local_count
        avg_ssim = local_ssim_total / local_count
        print(f" Folder Average - MSE: {avg_mse:.4f}, SSIM: {avg_ssim:.4f}")

# Global metrics
if global_count > 0:
    final_avg_mse = global_mse_total / global_count
    final_avg_ssim = global_ssim_total / global_count
    print(f"\n Final Global Average - MSE: {final_avg_mse:.4f}, SSIM: {final_avg_ssim:.4f}")

    # Showing 5 random examples for comparision
    print("\n Displaying 5 random examples across all folders:")
    random.shuffle(all_examples)
    for i in range(min(5, len(all_examples))):
        filename, ocr_img, gan_img, mse, ssim = all_examples[i]
        show_example(filename, ocr_img, gan_img, mse, ssim)
else:
    print("\n No valid image pairs were found for comparison.")
# Out:
#  Comparing:
#    GAN:  gan_generated_words\words_dataset_Mendo transcription_page_1_transcript
#    OCR:  ocr_generated_words\Mendo - Principe perfecto_page_1_words_corrected
#  Folder Average - MSE: 0.1330, SSIM: 0.4989
#
#  Comparing:
#    GAN:  gan_generated_words\words_dataset_Mendo transcription_page_2_transcript
#    OCR:  ocr_generated_words\Mendo - Principe perfecto_page_2_words_corrected
#  Skipping 15.png: no GAN counterpart.
#  Skipping 1659.png: no GAN counterpart.
#  Error loading cariño.png: cannot identify image file 'ocr_generated_words\\Mendo - Principe perfecto_page_2_words_corrected\\cariño.png'
#  Folder Average - MSE: 0.1404, SSIM: 0.4971
#
#  Comparing:
#    GAN:  gan_generated_words\words_dataset_Mendo transcription_page_3_transcript
#    OCR:  ocr_generated_words\Mendo - Principe perfecto_page_3_words_corrected
#  Skipping ;.png: no GAN counterpart.
#  Folder Average - MSE: 0.1613, SSIM: 0.4485
#
#  Comparing:
#    GAN:  gan_generated_words\words_dataset_Mendo transcription_page_4_transcript
#    OCR:  ocr_generated_words\Mendo - Principe perfecto_page_4_words_corrected
#  Folder Average - MSE: 0.1410, SSIM: 0.4822
#
#  Comparing:
#    GAN:  gan_generated_words\words_dataset_Mendo transcription_page_5_transcript
#    OCR:  ocr_generated_words\Mendo - Principe perfecto_page_5_words_corrected
#  Skipping 1656.png: no GAN counterpart.
#  Folder Average - MSE: 0.1304, SSIM: 0.4939
#
#  Final Global Average - MSE: 0.1423, SSIM: 0.4811
#
#  Displaying 5 random examples across all folders:
